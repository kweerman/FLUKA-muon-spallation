# %% [markdown]
# ## Read neutron file to compare different results

# %% [markdown]
# Mainly to compare hydrogen and carbon neutron capture rates -> remove (n,2n) interactions and such

# %%
neutronfile = open("/project/xenon/kweerman/exercises/XResults_isotopes/txt_neutrons/NeutronInfo21feb.txt", 'r')

total_ncount = neutronfile.readline().split()
no_neutrons, kton_neutron = int(total_ncount[5]), float(total_ncount[7])
print(no_neutrons, kton_neutron)
for lines in neutronfile:
    words = lines.split()
    print(words)
    
neutronfile.close()



#newfile = open("/project/xenon/kweerman/exercises/water/AZisotopesRESIDNUCwaterSortedOnA.txt",'w')
#for element_list in sorted_toA:
#    newfile.write("{0} {1} {2} {3:.4f}e-07\n".format(element_list[1],element_list[0],element_list[2],element_list[3]*1e7))
#newfile.close()
# Out:
# 8350749 3711.245708707626
# []
# ['Count', 'or', '(kton', 'day)^-1', 'and', 'particles', 'created']
# ['7735128', 'or', '3.437651e+03', ':', '[7,', '-3]']
# ['515921', 'or', '2.292860e+02', ':', '[7,', '-601207]']
# ['7260', 'or', '3.226494e+00', ':', '[1,', '7,', '-501207]']
# ['30699', 'or', '1.364327e+01', ':', '[7,', '-601307]']
# ['1684', 'or', '7.484045e-01', ':', '[7,', '7,', '7,', '7]']
# ['352', 'or', '1.564361e-01', ':', '[7]']
# ['29076', 'or', '1.292198e+01', ':', '[7,', '7,', '-601307]']
# ['9418', 'or', '4.185554e+00', ':', '[7,', '7]']
# ['2036', 'or', '9.048405e-01', ':', '[7,', '-501107,', '-3]']
# ['15198', 'or', '6.754306e+00', ':', '[7,', '7,', '7]']
# ['1516', 'or', '6.737418e-01', ':', '[1,', '7,', '7,', '-501207]']
# ['1100', 'or', '4.888628e-01', ':', '[7,', '7,', '-601207]']
# ['1299', 'or', '5.773025e-01', ':', '[7,', '7,', '7,', '-601207]']
# ['1', 'or', '4.444207e-04', ':', '[7,', '8]']
# ['45', 'or', '1.999893e-02', ':', '[7,', '7,', '7,', '7,', '7]']
# ...
